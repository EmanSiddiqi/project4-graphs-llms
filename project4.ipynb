# %% [markdown]
# Part 1: Prompt engineering

# %%
# !pip install google-generativeai

# %%
#we will be exploring google's python wrapper around their ai API
import os
import google.generativeai as genai

#generate your own key on https://aistudio.google.com/apikey
gemini_api_key = "AIzaSyCNcB91a_YupiHE_7kEyQ6bZrfP31lcg6A"

genai.configure(api_key=gemini_api_key)
multimodal_model = genai.GenerativeModel("gemini-1.5-flash-002")

# %%
#recall that text prompting and image prompting are both supported
model_response = multimodal_model.generate_content("hi, how was your day?")
model_response.text
# Out:
# "As a large language model, I don't experience days in the same way humans do. I don't have feelings or personal experiences.  However, I've been busy processing information and responding to many user requests.  So, in a sense, it's been a productive day! How was yours?\n"

# %%
from PIL import Image

img = Image.open("harrypotter.webp")
model_response = multimodal_model.generate_content(["how many male and female actors are in this image? return as list of two numbers: ", img])
model_response.text
# Out:
# '[2, 1]'

# %%
from transformers import pipeline
#download bert model
pipe = pipeline("text-classification", model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# Device set to use cpu

# %%
import pandas as pd
uiuc=pd.read_csv("uiuc.csv")
uiuc = uiuc.head(10)
sentimentsGEMINI=[]

# %%
from collections import Counter
sentiments=[]
i = 0
for text in uiuc["text"]:
  try:
    sentiment = pipe(text)
    sentiments.append(sentiment)
  except:
    print("Error at index:", i)
  i += 1
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (299 > 128). Running this sequence through the model will result in indexing errors
# Error at index: 18
# Error at index: 44
# Error at index: 63
# Error at index: 65
# Error at index: 67
# Error at index: 69
# Error at index: 79
# Error at index: 141
# Error at index: 143
# Error at index: 144
# Error at index: 157
# Error at index: 211
# Error at index: 223
# Error at index: 238
# Error at index: 239
# Error at index: 240
# Error at index: 241
# Error at index: 242
# Error at index: 243
# Error at index: 265
# Error at index: 372
# Error at index: 381
# Error at index: 416
# Error at index: 452
# Error at index: 453
# Error at index: 461
# Error at index: 546
# Error at index: 555
# Error at index: 560
# Error at index: 577
# Error at index: 615
# Error at index: 710
# Error at index: 735
# Error at index: 741
# Error at index: 756
# Error at index: 759
# Error at index: 787
# Error at index: 809
# Error at index: 837
# Error at index: 899
# Error at index: 920
# Error at index: 926
# Error at index: 952
# Error at index: 961
# Error at index: 986
# Error at index: 997
# Error at index: 1010
# Error at index: 1061
# Error at index: 1093
# Error at index: 1096
# Error at index: 1148
# Error at index: 1160
# Error at index: 1169
# Error at index: 1196
# Error at index: 1200
# Error at index: 1204
# Error at index: 1207
# Error at index: 1250
# Error at index: 1286
# Error at index: 1317
# Error at index: 1323
# Error at index: 1324
# Error at index: 1326
# Error at index: 1336
# Error at index: 1337
# Error at index: 1365
# Error at index: 1366
# Error at index: 1490
# Error at index: 1491
# Error at index: 1508
# Error at index: 1538
# Error at index: 1543
# Error at index: 1545
# Error at index: 1550
# Error at index: 1553
# Error at index: 1557
# Error at index: 1560
# Error at index: 1563
# Error at index: 1564
# Error at index: 1566
# Error at index: 1568
# Error at index: 1577
# Error at index: 1603
# Error at index: 1613
# Error at index: 1624
# Error at index: 1652
# Error at index: 1680
# Error at index: 1688
# Error at index: 1715
# Error at index: 1743
# Error at index: 1755
# Error at index: 1774
# Error at index: 1775
# Error at index: 1810
# Error at index: 1811
# Error at index: 1815
# Error at index: 1829
# Error at index: 1848
# Error at index: 1899
# Error at index: 1905
# Error at index: 1932
# Error at index: 1949
# Error at index: 1965
# Error at index: 1966
# Error at index: 2001
# Error at index: 2011
# Error at index: 2026
# Error at index: 2050
# Error at index: 2054
# Error at index: 2055
# Error at index: 2079
# Error at index: 2097
# Error at index: 2114
# Error at index: 2119
# Error at index: 2124
# Error at index: 2132
# Error at index: 2137
# Error at index: 2163
# Error at index: 2166
# Error at index: 2184
# Error at index: 2195
# Error at index: 2331
# Error at index: 2335
# Error at index: 2367
# Error at index: 2485
# Error at index: 2490
# Error at index: 2507
# Error at index: 2518
# Error at index: 2539
# Error at index: 2583
# Error at index: 2587
# Error at index: 2594
# Error at index: 2599
# Error at index: 2616
# Error at index: 2626
# Error at index: 2646
# Error at index: 2648
# Error at index: 2746
# Error at index: 2762
# Error at index: 2811
# Error at index: 2887
# Error at index: 2960
# Error at index: 2962
# Error at index: 2977
# Error at index: 2978
# Error at index: 3048
# Error at index: 3086
# Error at index: 3089
# Error at index: 3096
# Error at index: 3116
# Error at index: 3131
# Error at index: 3148
# Error at index: 3149
# Error at index: 3194
# Error at index: 3197
# Error at index: 3207
# Error at index: 3226
# Error at index: 3231
# Error at index: 3282
# Error at index: 3289
# Error at index: 3312
# Error at index: 3318
# Error at index: 3326
# Error at index: 3331
# Error at index: 3339
# Error at index: 3348
# Error at index: 3351
# Error at index: 3449
# Error at index: 3525
# Error at index: 3527
# Error at index: 3534
# Error at index: 3536
# Error at index: 3542
# Error at index: 3543
# Error at index: 3599
# Error at index: 3608
# Error at index: 3612
# Error at index: 3763
# Error at index: 3817
# Error at index: 3848
# Error at index: 3853
# Error at index: 3868
# Error at index: 3872
# Error at index: 3894
# Error at index: 3925
# Error at index: 3940
# Error at index: 3941
# Error at index: 4019
# Error at index: 4095
# Error at index: 4099
# Error at index: 4100
# Error at index: 4102
# Error at index: 4106
# Error at index: 4109
# Error at index: 4112
# Error at index: 4113
# Error at index: 4119
# Error at index: 4123
# Error at index: 4125
# Error at index: 4129
# Error at index: 4166
# Error at index: 4168
# Error at index: 4169
# Error at index: 4179
# Error at index: 4182
# Error at index: 4195
# Error at index: 4223
# Error at index: 4226
# Error at index: 4257
# Error at index: 4280
# Error at index: 4292
# Error at index: 4294
# Error at index: 4311
# Error at index: 4316
# Error at index: 4412
# Error at index: 4418
# Error at index: 4457
# Error at index: 4470
# Error at index: 4473
# Error at index: 4476
# Error at index: 4527
# Error at index: 4528
# Error at index: 4542
# Error at index: 4551
# Error at index: 4558
# Error at index: 4563
# Error at index: 4565
# Error at index: 4575
# Error at index: 4647

# %%
df_json = uiuc.to_json(orient='records')
model_response = multimodal_model.generate_content(["label each text in the dataset as positive ('POS'), negative ('NEG') or neutral ('NEU') only and output an array of the sentiments", df_json])

# %%
import re
flat_sentimentsBERT = []
flat_sentimentsGEMINI = []
for sentiment in sentiments:
    flat_sentimentsBERT.append(sentiment[0]['label'])

matches = re.findall(r'\b(NEU|POS|NEG)\b', model_response.text)

flat_sentimentsGEMINI.extend(matches)
# Count the occurrences of each sentiment label
sentiment_countsBERT = Counter(flat_sentimentsBERT)
sentiment_countsGEMINI = Counter(flat_sentimentsGEMINI)

# %%
print("BERT: " + str(sentiment_countsBERT['POS']) + " Gemini: " + str(sentiment_countsGEMINI['POS']))
print("BERT: " + str(sentiment_countsBERT['NEU']) + " Gemini: " + str(sentiment_countsGEMINI['NEU']))
print("BERT: " + str(sentiment_countsBERT['NEG']) + " Gemini: " + str(sentiment_countsGEMINI['NEG']))
#it seems that Gemini was unable to parse through many of the inputs - much less than bert, but seemed to label most things as either positive or neutral and not so much negative
#It seems that Bert is pretty balanced, but Gemini likes neutral and positive a lot
print(flat_sentimentsGEMINI[10] + " ", flat_sentimentsBERT[10])
print(uiuc["text"][10])
print(flat_sentimentsGEMINI[11] + " ", flat_sentimentsBERT[11])
print(uiuc["text"][11])
print(flat_sentimentsGEMINI[13] + " ", flat_sentimentsBERT[13])
print(uiuc["text"][13])
#I think the reason for the discrepancy is that Gemini looks at the meaning of each word rather than the context and BERT does the opposite
# Out:
# BERT: 1052 Gemini: 144
# BERT: 2336 Gemini: 651
# BERT: 1108 Gemini: 24
# NEG  NEU
# i dont think there is any cheap used one left
# NEG  POS
# One advantage of Perplexity over some other GenAIs is that it provides citations with its responses.
# POS  NEG
# Fed
#
#
# (although it's not like they would need to do any undercover work to figure this shit out lol)

# %%
#using the Gemini API, write a prompt to generate sentiment analysis on the same dataset

#make sure to includein the prompt a limit to the type of results (positive, negative, neutral)

#compare the sentiment percentages, what do you notice? Does one method overestimate or underestimate the sentiment of the dataset?

#find a few cases where their judgement differs, what do you think is the reason for the discrepancy? And which answer do you find more convincing?

# %% [markdown]
# Part 2: images

# %%
#download 10 images from the internet with a feature you're interested in studying. e.g. gender, race, age, action, etc.

#ask the model to annotate the images with the features you're interested in studying

#choose 2 objective (clear right or wrong answer) questions and ask the model to answer them, like how many people are in the image, or what is the color of the object in the image

#choose 2 subjective (open to interpretation) questions and ask the model to answer them, like what is the mood of the person in the image or what race/gender is the person

#look through the responses. Is there anything you disagree with? What do you think is the reason for the discrepancy? Would you trust large scale results generated for this annotation? b

# %%
img = Image.open("download.jpg")
model_response = multimodal_model.generate_content(["Annotate this image", img])
print(model_response.text)
img = Image.open("images.jpg")
model_response = multimodal_model.generate_content(["Annotate this image", img])
print(model_response.text)
#choose 2 objective (clear right or wrong answer) questions and ask the model to answer them, like how many people are in the image, or what is the color of the object in the image
img = Image.open("images.jpg")
model_response = multimodal_model.generate_content(["How many people are in this image?", img])
print(model_response.text)
img = Image.open("download.jpg")
model_response = multimodal_model.generate_content(["What is the background of the picture", img])
print(model_response.text)
#choose 2 subjective (open to interpretation) questions and ask the model to answer them, like what is the mood of the person in the image or what race/gender is the person
img = Image.open("images.jpg")
model_response = multimodal_model.generate_content(["What is the general mood of the people in this picture?", img])
print(model_response.text)
img = Image.open("download.jpg")
model_response = multimodal_model.generate_content(["What do you think is the favorite color of the majority?", img])
print(model_response.text)
#look through the responses. Is there anything you disagree with? What do you think is the reason for the discrepancy? Would you trust large scale results generated for this annotation? 
#I generally agreed with all of the responses the model gave. Even the response it gave for the color made sense since it definitely varies based on your culture and environment. I would trust the large scale results generated for this annotation.
# Out:
# That's a great photo! Here's a possible annotation, focusing on aspects that could be relevant depending on the context:
#
# **General Annotation:**
#
# * **Image Description:** A diverse group of young adults, eight individuals of varying ethnicities and gender expressions, are smiling and posing closely together for a photograph against a plain, light-grey background.  They appear happy and friendly.  The image conveys a sense of unity and inclusion.
#
# **More Specific Annotations (depending on intended use):**
#
# * **Diversity and Inclusion:** The image strongly emphasizes diversity in terms of ethnicity, gender, and possibly sexual orientation.  It could be used to illustrate concepts of inclusivity, multiculturalism, or belonging.
#
# * **Friendship and Camaraderie:** The close proximity and smiles suggest strong bonds of friendship or camaraderie within the group.
#
# * **Marketing/Advertising:** The image could be utilized in marketing campaigns related to inclusivity, diversity, youth culture, or a brand promoting values of acceptance and togetherness.
#
# * **Social Commentary:**  The photo could be used to illustrate a positive message of social cohesion and the celebration of differences in society.
#
#
# **Technical Annotations:**
#
# * **Photo Quality:** High-resolution image with good lighting and sharp focus.
# * **Composition:** The subjects are arranged in a visually appealing and dynamic way.
# * **Color Palette:** The overall color palette is warm and inviting, with a range of skin tones and clothing colors.
#
#
# To make this even more precise, consider adding these elements if you can determine them:
#
# * **Specific ethnicities/backgrounds represented:**  While not definitively identifiable from a photo alone, educated guesses about represented ethnicities could be added for greater specificity.
# * **Ages:** While appearing young adults, specifying a plausible age range would be helpful.
# * **Location of Photography:** If known.
# * **Source of image:** If it's from a stock photo site, name it.
#
# Remember to always be mindful and sensitive when annotating images of people. Avoid making assumptions or using language that could be perceived as stereotyping or offensive.
#
# Here's an annotation of the image:
#
# **Overall Scene:** A group of young adults, appearing to be friends, are gathered outdoors near a body of water at what looks like a festival or outdoor event during the golden hour (sunset/sunrise).  They are close together, exhibiting joyful and playful behavior.
#
# **Individuals & Actions:**
#
# * **Center (Taking Selfie):** A man with short brown hair and a light beard is taking a selfie with his smartphone. He's smiling broadly and appears to be the focal point of the group.  He's holding a plastic cup that appears to contain a light-colored beverage (likely beer).
#
# * **To his Left (Woman with dreadlocks):** A woman with long black dreadlocks is sticking her tongue out playfully. She's wearing layered necklaces and a bohemian-style top.
#
# * **To his left (Woman with dark hair):** A woman with shoulder-length brown hair is laughing and has her arm around the woman with dreadlocks. She is wearing a patterned top.
#
# * **To the woman's left (Man with short hair):** A man with short light brown hair is playfully kissing the woman on the cheek.  He appears slightly mischievous.
#
#
# * **To the selfie-taker's right (Man in the back):** A man with dark hair is partially visible behind the main group and is slightly out of focus. He seems to be enjoying the moment and joining in the fun.
#
#
# * **Far Left (Man with short, dark hair):**  A man with short, dark hair and a beard is raising his arms in celebration, his mouth open in what seems to be a yell or expression of joy.
#
# **Setting:**
#
# * **Background:** A calm body of water is visible in the background, along with some indistinct greenery and potentially some structures suggesting a park or festival setting.  The lighting suggests it's either early morning or late afternoon.
#
# **General Mood:** The overall mood is one of carefree fun, friendship, and celebration. The image evokes a feeling of summer, festivity, and youthful exuberance.
#
# **Image Source:** The watermark indicates the image is from Bigstock, a stock photo website.  This suggests the photo is a professionally taken stock image rather than a candid snapshot.
#
# That's a fun picture!  There are seven people in the image.
# That's a plain, off-white or light gray background.  It's intentionally simple and uncluttered to keep the focus entirely on the group of people in the foreground.
#
# That's a fun picture! The general mood of the people appears to be one of **exuberant joy, carefree fun, and close camaraderie.**  They're laughing, making silly faces, and clearly enjoying each other's company.  The setting (outdoors, near water, at sunset) also contributes to a feeling of relaxed happiness.
#
# That's a fun question!  It's impossible to tell the favorite color of the people in the image;  that requires asking them.
#
# However, based on numerous surveys conducted worldwide over many years, **blue** is consistently reported as the most popular color across a wide range of cultures and demographics.

# %% [markdown]
# Part 3: Network Demo

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\esidd\miniconda3\envs\is310\lib\site-packages (3.2.1)

# %%
import networkx as nx

# %%
#new graph
G = nx.Graph()

# %%
G.add_node(1)
G.add_nodes_from([2, 3])
#can add additional attributes to the nodes
G.add_nodes_from([(4, {"color": "red"}), (5, {"color": "green"})])

# %%
G.nodes[4]
# Out:
# {'color': 'red'}

# %%
list(G.nodes)
# Out:
# [1, 2, 3, 4, 5]

# %%
# can manually add edges too
G.add_edge(1, 2)

# %%
G.number_of_edges()
# Out:
# 1

# %%
#load edges from csv
import pandas as pd

edges = pd.read_csv("got-edges.csv")

G = nx.from_pandas_edgelist(edges, 'Source', 'Target')

# %%
G.number_of_edges()
# Out:
# 352

# %%
#visualize the graph

import matplotlib.pyplot as plt

nx.draw(G, with_labels=True)

plt.show()

# %%
#calculate the density of the graph

nx.density(G)
# Out:
# 0.062070181625815554

# %%
#return highest degree nodes

sorted(G.degree, key=lambda x: x[1], reverse=True)
# Out:
# [('Tyrion', 36),
#  ('Jon', 26),
#  ('Sansa', 26),
#  ('Robb', 25),
#  ('Jaime', 24),
#  ('Tywin', 22),
#  ('Cersei', 20),
#  ('Arya', 19),
#  ('Robert', 18),
#  ('Joffrey', 18),
#  ('Catelyn', 18),
#  ('Samwell', 15),
#  ('Bran', 14),
#  ('Stannis', 14),
#  ('Daenerys', 14),
#  ('Sandor', 13),
#  ('Mance', 12),
#  ('Gregor', 12),
#  ('Eddard', 12),
#  ('Lysa', 10),
#  ('Loras', 9),
#  ('Brynden', 8),
#  ('Walder', 8),
#  ('Edmure', 8),
#  ('Renly', 8),
#  ('Oberyn', 7),
#  ('Brienne', 7),
#  ('Petyr', 7),
#  ('Meryn', 7),
#  ('Varys', 7),
#  ('Margaery', 7),
#  ('Beric', 6),
#  ('Rickon', 6),
#  ('Balon', 6),
#  ('Barristan', 6),
#  ('Ilyn', 6),
#  ('Jorah', 6),
#  ('Rhaegar', 6),
#  ('Janos', 6),
#  ('Kevan', 6),
#  ('Aemon', 5),
#  ('Thoros', 5),
#  ('Meera', 5),
#  ('Podrick', 5),
#  ('Lothar', 5),
#  ('Elia', 5),
#  ('Shae', 5),
#  ('Craster', 5),
#  ('Davos', 5),
#  ('Tommen', 5),
#  ('Qhorin', 5),
#  ('Grenn', 4),
#  ('Aerys', 4),
#  ('Gendry', 4),
#  ('Roose', 4),
#  ('Belwas', 4),
#  ('Hodor', 4),
#  ('Jojen', 4),
#  ('Theon', 4),
#  ('Bronn', 4),
#  ('Roslin', 4),
#  ('Pycelle', 4),
#  ('Daario', 4),
#  ('Drogo', 4),
#  ('Irri', 4),
#  ('Gilly', 4),
#  ('Myrcella', 4),
#  ('Melisandre', 4),
#  ('Rattleshirt', 4),
#  ('Val', 4),
#  ('Ygritte', 4),
#  ('Alliser', 3),
#  ('Hoster', 3),
#  ('Viserys', 3),
#  ('Eddison', 3),
#  ('Dalla', 3),
#  ('Marillion', 3),
#  ('Robert Arryn', 3),
#  ('Mace', 3),
#  ('Anguy', 2),
#  ('Luwin', 2),
#  ('Nan', 2),
#  ('Jeyne', 2),
#  ('Missandei', 2),
#  ('Bowen', 2),
#  ('Styr', 2),
#  ('Jon Arryn', 2),
#  ('Olenna', 2),
#  ('Ellaria', 2),
#  ('Rickard', 2),
#  ('Chataya', 2),
#  ('Amory', 1),
#  ('Illyrio', 1),
#  ('Karl', 1),
#  ('Aegon', 1),
#  ('Kraznys', 1),
#  ('Rakharo', 1),
#  ('Worm', 1),
#  ('Cressen', 1),
#  ('Salladhor', 1),
#  ('Qyburn', 1),
#  ('Orell', 1),
#  ('Lancel', 1),
#  ('Ramsay', 1),
#  ('Shireen', 1),
#  ('Doran', 1),
#  ('Walton', 1)]

# %%
#make dataframes with nodes and a column for each centrality measure
df=pd.DataFrame(list(nx.degree_centrality(G).items()), columns=['node', 'degree'])
#add column for betweeness centrality
df['betweenness'] = list(nx.betweenness_centrality(G).values())
#add column for closeness centrality
df['closeness'] = list(nx.closeness_centrality(G).values())
#add column for eigenvector centrality
df['eigenvector'] = list(nx.eigenvector_centrality(G).values())

# %% [markdown]
# 3a. explore this dataframe, are there huge differences between these types of centrality? What might cause this?

# %%
df
# Out:
#         node    degree  betweenness  closeness  eigenvector
# 0      Aemon  0.047170     0.004623   0.389706     0.044139
# 1      Grenn  0.037736     0.000060   0.330218     0.019480
# 2    Samwell  0.141509     0.032273   0.384058     0.054346
# 3      Aerys  0.037736     0.000000   0.392593     0.078330
# 4      Jaime  0.226415     0.099943   0.479638     0.273663
# ..       ...       ...          ...        ...          ...
# 102   Ramsay  0.009434     0.000000   0.329193     0.018535
# 103  Chataya  0.018868     0.000000   0.340836     0.031102
# 104  Shireen  0.009434     0.000000   0.250000     0.001142
# 105    Doran  0.009434     0.000000   0.339744     0.025483
# 106   Walton  0.009434     0.000000   0.325153     0.020716
#
# [107 rows x 5 columns]

# %%
#calculate community structure
import networkx.algorithms.community as nxcom
communities = sorted(nxcom.greedy_modularity_communities(G), key=len, reverse=True)

#add community to node features

for i, community in enumerate(communities):
    for node in community:
        df.loc[df.node == node, "community"] = i

#color nodes by community
colors = df.community / df.community.max()

nx.draw(G, with_labels=True, node_color=colors, cmap=plt.cm.tab20)

plt.show()

# %% [markdown]
# Part 4: make your own social network. Take either a short excerpt of a novel, tv show, movie, or real life social network you are familiar with. Make a csv modelled off of the got-edges.csv with a Source, Target, and weight column. You need to decide what constitutes an edge and node, but easiest is characters or people connected by their number of interactions. You should manually type this into the csv. Include at least 25 edges
#
# What kind of potential issues did you run into while converting it into a graph? Any ambiguities that made it difficult to decide?
#
# use either Gephi or NetworkX to calculate node centrality and community features and add a visualization of the graph here. Does it align with your understanding of the media?

# %%
import pandas as pd
import random as random

df = pd.DataFrame(data)
df.to_csv('social_network.csv', index=False)

df = pd.DataFrame(data)
df.to_csv('social_network.csv', index=False)

# %%
edges = pd.read_csv("social_network.csv")
G = nx.from_pandas_edgelist(edges, 'Source', 'Target')

# %%
#make dataframes with nodes and a column for each centrality measure
df=pd.DataFrame(list(nx.degree_centrality(G).items()), columns=['node', 'degree'])
#add column for betweeness centrality
df['betweenness'] = list(nx.betweenness_centrality(G).values())
#add column for closeness centrality
df['closeness'] = list(nx.closeness_centrality(G).values())
#add column for eigenvector centrality
df['eigenvector'] = list(nx.eigenvector_centrality(G).values())

# %%
#calculate community structure
import networkx.algorithms.community as nxcom
communities = sorted(nxcom.greedy_modularity_communities(G), key=len, reverse=True)

#add community to node features

for i, community in enumerate(communities):
    for node in community:
        df.loc[df.node == node, "community"] = i

#color nodes by community
colors = df.community / df.community.max()

nx.draw(G, with_labels=True, node_color=colors, cmap=plt.cm.tab20)

plt.show()

# %% [markdown]
# When converting my custom social network into a graph, one of the main challenges I encountered was deciding what exactly counted as an "interaction" worthy of being an edge. Since I manually created the CSV file with at least 25 edges, I had to choose consistent criteria for weighting connections—such as how often two characters appeared together or interacted. Another difficulty was interpreting usernames or character labels that were ambiguous. For example, usernames like “Pokemon” or “Twin” raised the question of whether they referred to unique individuals or possible duplicates, which impacted how I structured the nodes. Additionally, because the dataset was created by hand, there’s an inherent risk of unintentionally under- or over-representing certain relationships, especially if the interactions were subtle or occurred in complex scenes.
#
# After importing the data into Gephi and running community detection and centrality analysis, the resulting graph provided some interesting insights. The visualization showed clear community clusters, each represented with a different color, likely based on modularity classes. Users like “soc-signals,” “musae-github,” and “Pokemon” appeared highly connected and central within their groups, while others were positioned more toward the edges of the graph. The circular layout helped me visually identify which characters or nodes acted as bridges between communities, and which ones were isolated or peripheral.
#
# Overall, the structure of the graph aligned well with my understanding of the network it represented. The tightly grouped clusters made sense based on known interactions, and the more central nodes reflected key figures in the network. A few surprises emerged—such as unexpected connections between distant groups—but this only highlighted the value of visualizing data to uncover hidden patterns. The graph not only made the network easier to understand but also opened up new ways of thinking about how characters or users relate to one another across different contexts.
